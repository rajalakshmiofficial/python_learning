# %%
import pandas as pd

# %%
df=pd.read_csv('C:\\Users\\2124259\\Downloads\\python practice\survey\survey_results_public.csv')
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
# ...

# %%
df['Country'].value_counts()
# Out:
# United States                         12469
# India                                  8403
# United Kingdom                         3896
# Germany                                3890
# Canada                                 2191
#                                       ...
# Chad                                      1
# Saint Lucia                               1
# Fiji                                      1
# Liechtenstein                             1
# Micronesia, Federated States of...        1
# Name: Country, Length: 183, dtype: int64

# %%
country_grp=df.groupby(['Country'])

# %%
country_grp.get_group('United States')
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 4               5  I used to be a developer by profession, but no...      Yes
# 7               8                     I am a developer by profession      Yes
# 13             14                     I am a developer by profession      Yes
# 16             17                     I am a developer by profession      Yes
# 17             18                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 64413       58498                                                NaN      Yes
# 64417       58896                                                NaN      Yes
# 64428       60931                                                NaN      Yes
# 64443       63077                                                NaN      Yes
# 64456       64858                                                NaN      Yes
#
# ...

# %%
country_grp.get_group('India')
# Out:
#        Respondent                              MainBranch Hobbyist   Age  \
# 6               7          I am a developer by profession      Yes   NaN
# 21             22          I am a developer by profession      Yes   NaN
# 57             58          I am a developer by profession      Yes   NaN
# 62             63  I am a student who is learning to code      Yes  21.0
# 147           149          I am a developer by profession      Yes  36.0
# ...           ...                                     ...      ...   ...
# 64391       54757                                     NaN      Yes   NaN
# 64398       55407                                     NaN      Yes   NaN
# 64439       62464                                     NaN      Yes   NaN
# 64442       62954                                     NaN      Yes   NaN
# 64452       64236                                     NaN      Yes   NaN
#
#       Age1stCode CompFreq   CompTotal  ConvertedComp Country  \
# ...

# %%
filt=df["Country"]=='United States'

# %%
df.loc[filt]
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 4               5  I used to be a developer by profession, but no...      Yes
# 7               8                     I am a developer by profession      Yes
# 13             14                     I am a developer by profession      Yes
# 16             17                     I am a developer by profession      Yes
# 17             18                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 64413       58498                                                NaN      Yes
# 64417       58896                                                NaN      Yes
# 64428       60931                                                NaN      Yes
# 64443       63077                                                NaN      Yes
# 64456       64858                                                NaN      Yes
#
# ...

# %%
filt=df["Country"]=='United States'
df.loc[filt]['NEWStuck'].value_counts()
# Out:
# Call a coworker or friend;Visit Stack Overflow;Go for a walk or other physical activity;Do other work and come back later                                                                   613
# Call a coworker or friend;Visit Stack Overflow;Go for a walk or other physical activity;Watch help / tutorial videos;Do other work and come back later                                      604
# Visit Stack Overflow;Go for a walk or other physical activity;Do other work and come back later                                                                                             565
# Visit Stack Overflow;Go for a walk or other physical activity;Watch help / tutorial videos;Do other work and come back later                                                                468
# Call a coworker or friend;Visit Stack Overflow;Do other work and come back later                                                                                                            410
# ...

# %%
country_grp['NEWStuck'].value_counts()
# Out:
# Country      NEWStuck
# Afghanistan  Visit Stack Overflow                                                                                                                                                                                                                 5
#              Visit Stack Overflow;Watch help / tutorial videos                                                                                                                                                                                    5
#              Call a coworker or friend;Visit Stack Overflow;Watch help / tutorial videos                                                                                                                                                          3
# ...

# %%
country_grp['NEWStuck'].value_counts().head(30)
# Out:
# Country      NEWStuck
# Afghanistan  Visit Stack Overflow                                                                                                                                                                                                                 5
#              Visit Stack Overflow;Watch help / tutorial videos                                                                                                                                                                                    5
#              Call a coworker or friend;Visit Stack Overflow;Watch help / tutorial videos                                                                                                                                                          3
# ...

# %%
country_grp['NEWStuck'].value_counts().loc['Albania']
# Out:
# NEWStuck
# Call a coworker or friend;Visit Stack Overflow                                                                                                                                                                                 3
# Visit Stack Overflow                                                                                                                                                                                                           3
# Visit Stack Overflow;Go for a walk or other physical activity;Watch help / tutorial videos;Do other work and come back later                                                                                                   3
# Call a coworker or friend;Visit Stack Overflow;Do other work and come back later                                                                                                                                               2
# ...

# %%
#country_grp['SocialMedia'].value_counts().loc['China']

# %%
country_grp['NEWStuck'].value_counts(normalize=True).loc['Albania']    #for %
# Out:
# NEWStuck
# Call a coworker or friend;Visit Stack Overflow                                                                                                                                                                                 0.078947
# Visit Stack Overflow                                                                                                                                                                                                           0.078947
# Visit Stack Overflow;Go for a walk or other physical activity;Watch help / tutorial videos;Do other work and come back later                                                                                                   0.078947
# Call a coworker or friend;Visit Stack Overflow;Do other work and come back later                                                                                                                                               0.052632
# ...

# %%
country_grp['ConvertedComp'].median().loc['Germany']
# Out:
# 62697.0

# %%
country_grp['ConvertedComp'].agg(['median','mean'])
# Out:
#                                        median           mean
# Country
# Afghanistan                           15163.5  148290.125000
# Albania                               15900.0   25611.000000
# Algeria                                9432.0   10362.812500
# Andorra                               88640.0   88640.000000
# Angola                                 5292.0    5292.000000
# ...                                       ...            ...
# Venezuela, Bolivarian Republic of...   3600.0    6280.611111
# Viet Nam                              10344.0   28342.605769
# Yemen                                 36000.0   36000.000000
# Zambia                                 5452.0   17506.400000
# Zimbabwe                               7200.0   26338.181818
#
# [183 rows x 2 columns]

# %%
country_grp['ConvertedComp'].agg(['median','mean']).loc['Canada']
# Out:
# median     68068.000000
# mean      115101.775465
# Name: Canada, dtype: float64

# %%
filt=df['Country']=="India"
df.loc[filt]['LanguageWorkedWith']
# Out:
# 6                                  C#;HTML/CSS;PHP
# 21                                     Java;Python
# 57                    C#;JavaScript;SQL;TypeScript
# 62           C;C++;HTML/CSS;Java;JavaScript;Python
# 147                 Bash/Shell/PowerShell;C++;Perl
#                            ...
# 64391    C;HTML/CSS;Java;JavaScript;PHP;Python;SQL
# 64398                                          NaN
# 64439                                          NaN
# 64442                                          SQL
# 64452                                          NaN
# Name: LanguageWorkedWith, Length: 8403, dtype: object

# %%
filt=df['Country']=="India"
df.loc[filt]['LanguageWorkedWith'].str.contains('Python')
# Out:
# 6        False
# 21        True
# 57       False
# 62        True
# 147      False
#          ...
# 64391     True
# 64398      NaN
# 64439      NaN
# 64442    False
# 64452      NaN
# Name: LanguageWorkedWith, Length: 8403, dtype: object

# %%
filt=df['Country']=="India"          #how many people know python
df.loc[filt]['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# 2670

# %%
#country_grp['LanguageWorkedWith'].str.contains('Python').sum()   check error
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-cda55dd00399> in <module>
# ----> 1 country_grp['LanguageWorkedWith'].str.contains('Python').sum()
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     750             return self[attr]
#     751
# --> 752         raise AttributeError(
#     753             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     754         )
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'str'

# %%
country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                              11
# Albania                                  13
# Algeria                                  40
# Andorra                                   3
# Angola                                    1
#                                        ...
# Venezuela, Bolivarian Republic of...     29
# Viet Nam                                102
# Yemen                                     1
# Zambia                                    4
# Zimbabwe                                 13
# Name: LanguageWorkedWith, Length: 183, dtype: int64

# %%
#what total no of people who know python?
#what %of people from each country know python?

# %%
country_respondents=df['Country'].value_counts()
country_respondents
# Out:
# United States                         12469
# India                                  8403
# United Kingdom                         3896
# Germany                                3890
# Canada                                 2191
#                                       ...
# Chad                                      1
# Saint Lucia                               1
# Fiji                                      1
# Liechtenstein                             1
# Micronesia, Federated States of...        1
# Name: Country, Length: 183, dtype: int64

# %%
country_uses_python=country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())

# %%
country_uses_python
# Out:
# Country
# Afghanistan                              11
# Albania                                  13
# Algeria                                  40
# Andorra                                   3
# Angola                                    1
#                                        ...
# Venezuela, Bolivarian Republic of...     29
# Viet Nam                                102
# Yemen                                     1
# Zambia                                    4
# Zimbabwe                                 13
# Name: LanguageWorkedWith, Length: 183, dtype: int64

# %%
#total no of people so concate

# %%
python_df=pd.concat([country_respondents, country_uses_python],axis='columns',sort=False)
python_df
# Out:
#                                     Country  LanguageWorkedWith
# United States                         12469                5964
# India                                  8403                2670
# United Kingdom                         3896                1621
# Germany                                3890                1712
# Canada                                 2191                1011
# ...                                     ...                 ...
# Chad                                      1                   0
# Saint Lucia                               1                   1
# Fiji                                      1                   0
# Liechtenstein                             1                   0
# Micronesia, Federated States of...        1                   1
#
# [183 rows x 2 columns]

# %%
#rename

# %%
python_df.rename(columns={'Country':'NumRespondents','LanguageWorkedWith':'Numknowspython'},inplace=True)
python_df
# Out:
#                                     NumRespondents  Numknowspython
# United States                                12469            5964
# India                                         8403            2670
# United Kingdom                                3896            1621
# Germany                                       3890            1712
# Canada                                        2191            1011
# ...                                            ...             ...
# Chad                                             1               0
# Saint Lucia                                      1               1
# Fiji                                             1               0
# Liechtenstein                                    1               0
# Micronesia, Federated States of...               1               1
#
# [183 rows x 2 columns]

# %%
#new column create %value of mean

# %%
#python_df['pctknowspython']=part/whole

# %%
python_df['pctknowspython']=(python_df['Numknowspython']/python_df['NumRespondents'])*100
python_df
# Out:
#                                     NumRespondents  Numknowspython  \
# United States                                12469            5964
# India                                         8403            2670
# United Kingdom                                3896            1621
# Germany                                       3890            1712
# Canada                                        2191            1011
# ...                                            ...             ...
# Chad                                             1               0
# Saint Lucia                                      1               1
# Fiji                                             1               0
# Liechtenstein                                    1               0
# Micronesia, Federated States of...               1               1
#
#                                     pctknowspython
# United States                            47.830620
# India                                    31.774366
# ...

# %%
python_df.sort_values(by='pctknowspython',ascending=False)
python_df
# Out:
#                                     NumRespondents  Numknowspython  \
# United States                                12469            5964
# India                                         8403            2670
# United Kingdom                                3896            1621
# Germany                                       3890            1712
# Canada                                        2191            1011
# ...                                            ...             ...
# Chad                                             1               0
# Saint Lucia                                      1               1
# Fiji                                             1               0
# Liechtenstein                                    1               0
# Micronesia, Federated States of...               1               1
#
#                                     pctknowspython
# United States                            47.830620
# India                                    31.774366
# ...
