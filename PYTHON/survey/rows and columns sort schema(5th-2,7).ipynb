# %%
import pandas as pd

# %%
people={'first':['cin','anu','ais'],
       'middle':['de','de','en'],
       'last':['fu','en','fu'],
       'email':['cin@gamail.com','anu@gamail.com','aisha@gamail.com']}

# %%
df=pd.DataFrame(people)
df
# Out:
#   first middle last             email
# 0   cin     de   fu    cin@gamail.com
# 1   anu     de   en    anu@gamail.com
# 2   ais     en   fu  aisha@gamail.com

# %%
df.apply(pd.Series.min)      #to find which alphabets 1st in each column
# Out:
# first                  ais
# middle                  de
# last                    en
# email     aisha@gamail.com
# dtype: object

# %%
df.apply(lambda x: x.min())         #to find which alphabets 1st in each column to use lambda
# Out:
# first                  ais
# middle                  de
# last                    en
# email     aisha@gamail.com
# dtype: object

# %%
df.applymap(len)     #built in len function to map every individal len of dataframe use applymap
# Out:
#    first  middle  last  email
# 0      3       2     2     14
# 1      3       2     2     14
# 2      3       2     2     16

# %%
#to map all values in dataframe in lowercase
df.applymap(str.lower)
# Out:
#   first middle last             email
# 0   cin     de   fu    cin@gamail.com
# 1   anu     de   en    anu@gamail.com
# 2   ais     en   fu  aisha@gamail.com

# %%
df.applymap(str.upper)
# Out:
#   first middle last             email
# 0   CIN     DE   FU    CIN@GAMAIL.COM
# 1   ANU     DE   EN    ANU@GAMAIL.COM
# 2   AIS     EN   FU  AISHA@GAMAIL.COM

# %%
#to chqnge 1 column values by use substitute
df['first'].map({'cin':'tin','anu':'Manu'})
# Out:
# 0     tin
# 1    Manu
# 2     NaN
# Name: first, dtype: object

# %%
df['first'].replace({'cin':'tin','anu':'Manu'})  #instead of map we use replace so you don have nan
# Out:
# 0     tin
# 1    Manu
# 2     ais
# Name: first, dtype: object

# %%
#rename column name
df.rename(columns={'first':'foremost'},inplace=True)

# %%
df['foremost']
# Out:
# 0    cin
# 1    anu
# 2    ais
# Name: foremost, dtype: object

# %%
#rename column name(2)
df.rename(columns={'first':'foremost'})
# Out:
#   foremost middle last             email
# 0      cin     de   fu    cin@gamail.com
# 1      anu     de   en    anu@gamail.com
# 2      ais     en   fu  aisha@gamail.com

# %%
#2 ansku another itha apply panrathu like true or false vachu
df['last'].map({'fu':'True','en':'False'})
# Out:
# 0     True
# 1    False
# 2     True
# Name: last, dtype: object

# %%
df['last'].map({'fu':'True'})
# Out:
# 0    True
# 1     NaN
# 2    True
# Name: last, dtype: object

# %%
df['last'].replace({'fu':'True','en':'False'})
# Out:
# 0     True
# 1    False
# 2     True
# Name: last, dtype: object

# %%
df.describe()
# Out:
#        foremost middle last           email
# count         3      3    3               3
# unique        3      2    2               3
# top         ais     de   fu  cin@gamail.com
# freq          1      2    2               1

# %%
import pandas as pd

# %%
df=pd.read_csv('C:\\Users\\2124259\\Downloads\\python practice\survey\survey_results_public.csv')
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
# ...

# %%
schema_df=pd.read_csv('C:\\Users\\2124259\\Downloads\\python practice\survey\survey_results_schema.csv')
schema_df
# Out:
#                 Column                                       QuestionText
# 0           Respondent  Randomized respondent ID number (not in order ...
# 1           MainBranch  Which of the following options best describes ...
# 2             Hobbyist                            Do you code as a hobby?
# 3                  Age  What is your age (in years)? If you prefer not...
# 4           Age1stCode  At what age did you write your first line of c...
# ..                 ...                                                ...
# 56  WebframeWorkedWith  Which web frameworks have you done extensive d...
# 57       WelcomeChange  Compared to last year, how welcome do you feel...
# 58         WorkWeekHrs  On average, how many hours per week do you wor...
# 59           YearsCode  Including any education, how many years have y...
# 60        YearsCodePro  NOT including education, how many years have y...
#
# [61 rows x 2 columns]

# %%
df['Country']
# Out:
# 0                   Germany
# 1            United Kingdom
# 2        Russian Federation
# 3                   Albania
# 4             United States
#                 ...
# 64456         United States
# 64457               Morocco
# 64458              Viet Nam
# 64459                Poland
# 64460                 Spain
# Name: Country, Length: 64461, dtype: object

# %%
#df.sort_values('Country',inplace=True).head(30)   error
df.sort_values('Country',inplace=True)
df['Country'].head(30)
# Out:
# 8599     Afghanistan
# 24908    Afghanistan
# 57044    Afghanistan
# 41950    Afghanistan
# 50469    Afghanistan
# 37601    Afghanistan
# 28270    Afghanistan
# 9806     Afghanistan
# 50492    Afghanistan
# 35541    Afghanistan
# 36354    Afghanistan
# 43140    Afghanistan
# 63925    Afghanistan
# 38261    Afghanistan
# 35602    Afghanistan
# 43010    Afghanistan
# 36887    Afghanistan
# 43708    Afghanistan
# 61453    Afghanistan
# 64306    Afghanistan
# 43157    Afghanistan
# 23708    Afghanistan
# 41506    Afghanistan
# 2918     Afghanistan
# 63993    Afghanistan
# 43843    Afghanistan
# 59329    Afghanistan
# 895      Afghanistan
# 50847    Afghanistan
# 35052    Afghanistan
# Name: Country, dtype: object

# %%
df.sort_values(by='ConvertedComp',ascending=False)
# Out:
#        Respondent                      MainBranch Hobbyist   Age Age1stCode  \
# 56482       57606  I am a developer by profession       No  23.0         16
# 4109         4125  I am a developer by profession      Yes  24.0         15
# 4113         4129  I am a developer by profession      Yes  23.0         16
# 52361       53444  I am a developer by profession      Yes   NaN         12
# 52360       53443  I am a developer by profession      Yes  20.0         18
# ...           ...                             ...      ...   ...        ...
# 64425       60055                             NaN       No   NaN        NaN
# 64431       61121                             NaN      Yes   NaN        NaN
# 64434       61570                             NaN       No   NaN        NaN
# 64436       61918                             NaN      Yes   NaN        NaN
# 64440       62605                             NaN       No   NaN        NaN
#
# ...

# %%
df.sort_values(by='ConvertedComp',ascending=False).head(60)
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 56482       57606                     I am a developer by profession       No
# 4109         4125                     I am a developer by profession      Yes
# 4113         4129                     I am a developer by profession      Yes
# 52361       53444                     I am a developer by profession      Yes
# 52360       53443                     I am a developer by profession      Yes
# 58754       59916                     I am a developer by profession       No
# 4459         4475                     I am a developer by profession      Yes
# 15567       15619                     I am a developer by profession      Yes
# 19586       19664                     I am a developer by profession      Yes
# 2126         2135                     I am a developer by profession      Yes
# 3031         3045                     I am a developer by profession      Yes
# ...

# %%
df['Age'].nlargest(70)   #to grab particular column highest
# Out:
# 14375    279.0
# 50963     99.0
# 2625      99.0
# 26740     99.0
# 56904     99.0
#          ...
# 55266     73.0
# 3073      73.0
# 14395     73.0
# 3202      73.0
# 1963      73.0
# Name: Age, Length: 70, dtype: float64

# %%
df.nlargest(10,'Age')           #to grab all columns
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 14375       14419                     I am a developer by profession      Yes
# 50963       52018  I used to be a developer by profession, but no...      Yes
# 2625         2638                     I am a developer by profession       No
# 26740       26839             I am a student who is learning to code      Yes
# 56904       58030             I am a student who is learning to code      Yes
# 47567       48563                     I am a developer by profession      Yes
# 45324       46268                     I am a developer by profession      Yes
# 56725       57850                     I am a developer by profession       No
# 5926         5950                     I am a developer by profession      Yes
# 52838       53925                        I code primarily as a hobby      Yes
#
#          Age            Age1stCode CompFreq     CompTotal  ConvertedComp  \
# ...

# %%
df.nsmallest(20,'Age')
# Out:
#        Respondent                              MainBranch Hobbyist   Age  \
# 64383       52582                                     NaN      Yes   1.0
# 20042       20122          I am a developer by profession      Yes   1.0
# 58292       59438          I am a developer by profession      Yes   1.0
# 25061       25154          I am a developer by profession      Yes   1.0
# 12271       12310  I am a student who is learning to code      Yes   1.0
# 54687       55797          I am a developer by profession      Yes   1.0
# 8793         8825  I am a student who is learning to code      Yes   3.0
# 11600       11638  I am a student who is learning to code      Yes   5.0
# 26952       27051             I code primarily as a hobby      Yes   7.0
# 25432       25526          I am a developer by profession       No  10.0
# 30810       30927          I am a developer by profession      Yes  10.0
# 17852       17916             I code primarily as a hobby      Yes  10.0
# ...

# %%
df['Age'].nsmallest(10)
# Out:
# 64383     1.0
# 20042     1.0
# 58292     1.0
# 25061     1.0
# 12271     1.0
# 54687     1.0
# 8793      3.0
# 11600     5.0
# 26952     7.0
# 25432    10.0
# Name: Age, dtype: float64

# %%
#df[['Age','ConvertedComp'],.nlargest(10),.nsmallest(5)]
df.sort_values(by=['Age','ConvertedComp'],ascending=[False,True])
df
# Out:
#        Respondent                      MainBranch Hobbyist    Age  \
# 14375       14419  I am a developer by profession      Yes  279.0
# 47567       48563  I am a developer by profession      Yes   99.0
# 5926         5950  I am a developer by profession      Yes   99.0
# 45324       46268  I am a developer by profession      Yes   99.0
# 2625         2638  I am a developer by profession       No   99.0
# ...           ...                             ...      ...    ...
# 64425       60055                             NaN       No    NaN
# 64431       61121                             NaN      Yes    NaN
# 64434       61570                             NaN       No    NaN
# 64436       61918                             NaN      Yes    NaN
# 64440       62605                             NaN       No    NaN
#
#           Age1stCode CompFreq     CompTotal  ConvertedComp      Country  \
# 14375             16   Yearly  4.900000e+04        52968.0  Netherlands
# ...

# %%
df.sort_values(by=['Country','ConvertedComp'],ascending=[True,False],inplace=True)
df
# Out:
#        Respondent                      MainBranch Hobbyist  Age  \
# 63925       65381  I am a developer by profession       No  NaN
# 63993       65456  I am a developer by profession      Yes  NaN
# 61540       62788  I am a developer by profession      Yes  NaN
# 38261       38672  I am a developer by profession       No  NaN
# 28270       28374  I am a developer by profession      Yes  NaN
# ...           ...                             ...      ...  ...
# 64425       60055                             NaN       No  NaN
# 64431       61121                             NaN      Yes  NaN
# 64434       61570                             NaN       No  NaN
# 64436       61918                             NaN      Yes  NaN
# 64440       62605                             NaN       No  NaN
#
#                  Age1stCode CompFreq     CompTotal  ConvertedComp  \
# 63925                     8   Weekly  8.740000e+09      1000000.0
# ...

# %%
df[['Country','ConvertedComp']].head(30)
# Out:
#            Country  ConvertedComp
# 63925  Afghanistan      1000000.0
# 63993  Afghanistan      1000000.0
# 61540  Afghanistan      1000000.0
# 38261  Afghanistan       231192.0
# 28270  Afghanistan       130000.0
# 9806   Afghanistan        23328.0
# 62520  Afghanistan        23328.0
# 50812  Afghanistan        20950.0
# 50469  Afghanistan        20220.0
# 43642  Afghanistan        18660.0
# 15371  Afghanistan        18000.0
# 2918   Afghanistan        16335.0
# 26443  Afghanistan        13992.0
# 56146  Afghanistan        10884.0
# 26676  Afghanistan         8016.0
# 30451  Afghanistan         5448.0
# 30405  Afghanistan         4668.0
# 28704  Afghanistan         4509.0
# 34842  Afghanistan         4356.0
# 26758  Afghanistan         2328.0
# 33755  Afghanistan         1860.0
# 35602  Afghanistan          780.0
# 17985  Afghanistan          109.0
# 35168  Afghanistan            0.0
# 54129  Afghanistan            NaN
# 43157  Afghanistan            NaN
# ...

# %%
#doubt after sort index position only sort? bcz after change index sort is deisappear
#doubt .nlargest,.nsmallesta 2 columns use panalama?
