# %%
import pandas as pd

# %%
df=pd.read_csv('C:\\Users\\2124259\\Downloads\\python practice\survey\survey_results_public.csv',index_col='Respondent')
df
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
# ...                                                       ...      ...   ...
# 64858                                                     NaN      Yes   NaN
# 64867                                                     NaN      Yes   NaN
# 64898                                                     NaN      Yes   NaN
# 64925                                                     NaN      Yes   NaN
# 65112                                                     NaN      Yes   NaN
#
# ...

# %%
highsalary=(df['ConvertedComp']>80000)
highsalary #this condition satify panra all rows and all colums print agum.
# Out:
# Respondent
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
#          ...
# 64858    False
# 64867    False
# 64898    False
# 64925    False
# 65112    False
# Name: ConvertedComp, Length: 64461, dtype: bool

# %%
df.loc[highsalary]
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 8                              I am a developer by profession      Yes  36.0
# 16                             I am a developer by profession      Yes  45.0
# 18                             I am a developer by profession      Yes  32.0
# 19                             I am a developer by profession       No  24.0
# 24                             I am a developer by profession      Yes  45.0
# ...                                                       ...      ...   ...
# 65586                          I am a developer by profession      Yes   NaN
# 65589                          I am a developer by profession      Yes   NaN
# 65602       I am not primarily a developer, but I write co...      Yes   NaN
# 65604                          I am a developer by profession       No   NaN
# 65617                          I am a developer by profession      Yes   NaN
#
# ...

# %%
df.loc[highsalary,['Country','LanguageWorkedWith','ConvertedComp']]    #this condition satified rows and given columns insted of all columns

# %%
countries=['United States','India','Canada']
filt=df['Country'].isin(countries)
df.loc[filt,['LanguageWorkedWith','Country']]

#df.loc[filt,['Country','JobSeek']]
#df.loc[filt] #like given all columns get printed

# %%
# requirement===i want in langwidth in python only and without na values
filt=df['LanguageWorkedWith'].str.contains('Python',na=False)
#if i given small p i got error
##filt  #boolean values got
df.loc[filt,'LanguageWorkedWith']

# %%
df=pd.read_csv('C:\\Users\\2124259\\Downloads\\python practice\survey\survey_results_public.csv')
df

# %%
people={'first':['cin','anu','ais'],
       'middle':['de','de','en'],
       'last':['fu','en','fu'],
       'email':['cin@gamail.com','anu@gamail.com','aisha@gamail.com']}

# %%
import pandas as pd

# %%
df=pd.DataFrame(people)
df

# %%
df['last']=='fu' #boolean value

# %%
filt=(df['last']=='fu')
#df[filt]
df.loc[filt] #or we use df.loc[filt]

# %%
df[df['last']=='fu']        #direct call
# Out:
#   first middle last             email
# 0   cin     de   fu    cin@gamail.com
# 2   ais     en   fu  aisha@gamail.com

# %%
df.loc[filt,['email','last','first']]
# Out:
#               email last first
# 0    cin@gamail.com   fu   cin
# 2  aisha@gamail.com   fu   ais

# %%
filt=(df['last']=='fu') & (df['first']=='ais')

# %%
df[filt]
# Out:
#   first middle last             email
# 2   ais     en   fu  aisha@gamail.com

# %%
filt=(df['last']=='fu') | (df['first']=='ais')
df[filt]
# Out:
#   first middle last             email
# 0   cin     de   fu    cin@gamail.com
# 2   ais     en   fu  aisha@gamail.com

# %%
filt=(df['last']=='fu') | (df['first']=='ais')
#df[~filt]
df.loc[~filt]
#use negotiation also
# Out:
#   first middle last           email
# 1   anu     de   en  anu@gamail.com
