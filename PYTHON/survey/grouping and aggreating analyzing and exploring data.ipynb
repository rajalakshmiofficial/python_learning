# %%
import pandas as pd

df=pd.read_csv('C:\\Users\\2124259\\Downloads\\python practice\survey\survey_results_public.csv')

schema_df=pd.read_csv('C:\\Users\\2124259\\Downloads\\python practice\survey\survey_results_schema.csv')

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
# ...

# %%
schema_df
# Out:
#                 Column                                       QuestionText
# 0           Respondent  Randomized respondent ID number (not in order ...
# 1           MainBranch  Which of the following options best describes ...
# 2             Hobbyist                            Do you code as a hobby?
# 3                  Age  What is your age (in years)? If you prefer not...
# 4           Age1stCode  At what age did you write your first line of c...
# ..                 ...                                                ...
# 56  WebframeWorkedWith  Which web frameworks have you done extensive d...
# 57       WelcomeChange  Compared to last year, how welcome do you feel...
# 58         WorkWeekHrs  On average, how many hours per week do you wor...
# 59           YearsCode  Including any education, how many years have y...
# 60        YearsCodePro  NOT including education, how many years have y...
#
# [61 rows x 2 columns]

# %%
schema_df.iloc[0]
# Out:
# Column                                                 Respondent
# QuestionText    Randomized respondent ID number (not in order ...
# Name: 0, dtype: object

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1                     I am a developer by profession      Yes
# 1           2                     I am a developer by profession       No
# 2           3                        I code primarily as a hobby      Yes
# 3           4                     I am a developer by profession      Yes
# 4           5  I used to be a developer by profession, but no...      Yes
#
#     Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0   NaN         13  Monthly        NaN            NaN             Germany
# 1   NaN         19      NaN        NaN            NaN      United Kingdom
# 2   NaN         15      NaN        NaN            NaN  Russian Federation
# 3  25.0         18      NaN        NaN            NaN             Albania
# 4  31.0         16      NaN        NaN            NaN       United States
#
# ...

# %%
df['ConvertedComp'].head(15)
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7     116000.0
# 8          NaN
# 9      32315.0
# 10     40070.0
# 11     14268.0
# 12     38916.0
# 13     66000.0
# 14         NaN
# Name: ConvertedComp, dtype: float64

# %%
#df['ConvertedComp'].median()

df['WorkWeekHrs'].median()
# Out:
# 40.0

# %%
#df.median().head(3) 
df.median()   #to show all median
# Out:
# Respondent       32231.0
# Age                 29.0
# CompTotal        63000.0
# ConvertedComp    54049.0
# WorkWeekHrs         40.0
# dtype: float64

# %%
df.describe()   #it overview all items describe
# Out:
#          Respondent           Age      CompTotal  ConvertedComp   WorkWeekHrs
# count  64461.000000  45446.000000   3.482600e+04   3.475600e+04  41151.000000
# mean   32554.079738     30.834111  3.190464e+242   1.037561e+05     40.782174
# std    18967.442360      9.585392            inf   2.268853e+05     17.816383
# min        1.000000      1.000000   0.000000e+00   0.000000e+00      1.000000
# 25%    16116.000000     24.000000   2.000000e+04   2.464800e+04     40.000000
# 50%    32231.000000     29.000000   6.300000e+04   5.404900e+04     40.000000
# 75%    49142.000000     35.000000   1.250000e+05   9.500000e+04     44.000000
# max    65639.000000    279.000000  1.111111e+247   2.000000e+06    475.000000

# %%
df['ConvertedComp'].count()   #it gives count for non nan value
# Out:
# 34756

# %%
df['Hobbyist'].value_counts()    #it gives all different entries of that columns
# Out:
# Yes    50388
# No     14028
# Name: Hobbyist, dtype: int64

# %%
df['Hobbyist']
# Out:
# 0        Yes
# 1         No
# 2        Yes
# 3        Yes
# 4        Yes
#         ...
# 64456    Yes
# 64457    Yes
# 64458    Yes
# 64459    Yes
# 64460    Yes
# Name: Hobbyist, Length: 64461, dtype: object

# %%
df['PlatformWorkedWith']
# Out:
# 0                                           Windows
# 1                                               iOS
# 2                                               NaN
# 3                                               NaN
# 4                    AWS;Docker;Linux;MacOS;Windows
#                             ...
# 64456                                           NaN
# 64457                                           NaN
# 64458                                           NaN
# 64459                                 Linux;Windows
# 64460    Android;Arduino;Linux;Raspberry Pi;Windows
# Name: PlatformWorkedWith, Length: 64461, dtype: object

# %%
df['CompTotal']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#          ..
# 64456   NaN
# 64457   NaN
# 64458   NaN
# 64459   NaN
# 64460   NaN
# Name: CompTotal, Length: 64461, dtype: float64

# %%
schema_df=pd.read_csv('C:\\Users\\2124259\\Downloads\\python practice\survey\survey_results_schema.csv')

# %%
schema_df
# Out:
#                 Column                                       QuestionText
# 0           Respondent  Randomized respondent ID number (not in order ...
# 1           MainBranch  Which of the following options best describes ...
# 2             Hobbyist                            Do you code as a hobby?
# 3                  Age  What is your age (in years)? If you prefer not...
# 4           Age1stCode  At what age did you write your first line of c...
# ..                 ...                                                ...
# 56  WebframeWorkedWith  Which web frameworks have you done extensive d...
# 57       WelcomeChange  Compared to last year, how welcome do you feel...
# 58         WorkWeekHrs  On average, how many hours per week do you wor...
# 59           YearsCode  Including any education, how many years have y...
# 60        YearsCodePro  NOT including education, how many years have y...
#
# [61 rows x 2 columns]

# %%
#schema_df.loc['Respondent']

# %%
df['PlatformWorkedWith'].value_counts()
# Out:
# Windows                                                                                             4770
# Linux;Windows                                                                                       2461
# Linux                                                                                               2112
# Android                                                                                             1201
# Microsoft Azure;Windows                                                                              996
#                                                                                                     ...
# AWS;Docker;Kubernetes;Linux;MacOS;Microsoft Azure;Slack Apps and Integrations;WordPress                1
# Android;Arduino;AWS;iOS;Windows                                                                        1
# AWS;Docker;iOS;Kubernetes;Microsoft Azure;Windows                                                      1
# ...

# %%
df['PlatformWorkedWith'].value_counts(normalize=True)       #to get %value
# Out:
# Windows                                                                                             0.088591
# Linux;Windows                                                                                       0.045707
# Linux                                                                                               0.039225
# Android                                                                                             0.022306
# Microsoft Azure;Windows                                                                             0.018498
#                                                                                                       ...
# AWS;Docker;Kubernetes;Linux;MacOS;Microsoft Azure;Slack Apps and Integrations;WordPress             0.000019
# Android;Arduino;AWS;iOS;Windows                                                                     0.000019
# AWS;Docker;iOS;Kubernetes;Microsoft Azure;Windows                                                   0.000019
# ...

# %%
#group
#1.split 2.applyfun 3.combine results

# %%
df['Country'].value_counts()
# Out:
# United States       12469
# India                8403
# United Kingdom       3896
# Germany              3890
# Canada               2191
#                     ...
# Fiji                    1
# Marshall Islands        1
# Kiribati                1
# Mali                    1
# North Korea             1
# Name: Country, Length: 183, dtype: int64

# %%
#

df.groupby=df.groupby(['Country']) #no output

# %%
df['Country']
#country_grp.get_group('United States')
# Out:
# 0                   Germany
# 1            United Kingdom
# 2        Russian Federation
# 3                   Albania
# 4             United States
#                 ...
# 64456         United States
# 64457               Morocco
# 64458              Viet Nam
# 64459                Poland
# 64460                 Spain
# Name: Country, Length: 64461, dtype: object

# %%
#Country_grp.get_groupby('United States')
Country_grp=df.groupby(['Country'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-7cdad9b3309b> in <module>
#       1 #Country_grp.get_groupby('United States')
# ----> 2 Country_grp=df.groupby(['Country'])
#
# TypeError: 'DataFrameGroupBy' object is not callable

# %%
df.groupby=df.groupby[('Age')]

# %%
country_grp=df.groupby['Age']
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-28-3268f128768c> in <module>
# ----> 1 country_grp=df.groupby['Age']
#
# ~\Anaconda3\lib\site-packages\pandas\core\base.py in __getitem__(self, key)
#     253     def __getitem__(self, key):
#     254         if self._selection is not None:
# --> 255             raise IndexError(f"Column(s) {self._selection} already selected")
#     256
#     257         if isinstance(key, (list, tuple, ABCSeries, ABCIndexClass, np.ndarray)):
#
# IndexError: Column(s) Age already selected

# %%
filt=df['Country']=='United States'

# %%
df.loc(filt)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-fabefab01115> in <module>
# ----> 1 df.loc(filt)
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __call__(self, axis)
#     605
#     606         if axis is not None:
# --> 607             axis = self.obj._get_axis_number(axis)
#     608         new_self.axis = axis
#     609         return new_self
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_axis_number(cls, axis)
#     458     def _get_axis_number(cls, axis: Axis) -> int:
#     459         try:
# --> 460             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     461         except KeyError:
#     462             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __hash__(self)
#    1783
#    1784     def __hash__(self) -> int:
# ...

# %%
country_grp = df.groupby(['Country'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-94ab6c823205> in <module>
# ----> 1 country_grp = df.groupby(['Country'])
#
# TypeError: 'SeriesGroupBy' object is not callable
